# %%
# importing all necessary modules
import pandas as pd
from gensim.models import Word2Vec
import gensim
from nltk.tokenize import sent_tokenize, word_tokenize
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Get open positions and transformed datasets

# %%
#get the open positions dataset from web scraping
open_positions = pd.read_csv(r".\linkedin_jobs_scraping.csv")

#get all companies dataset from web scraping
all_companies = pd.read_csv(r".\all_companies_scraping.csv")

#get the data after some transformations - extract the descriptions of past jobs (from databricks)
df = pd.read_csv(r".\transformed_df.csv")
df['is_in_similarities'] = df['url'].apply(lambda x: str(x) in list_urls_similar)

#save the new dataframe
df.to_csv('with_column_is_similar.csv',index = False)

# all people from linkedin dataset
df = pd.read_csv('with_column_is_similar.csv') 

# get the people that similar from the first model
profile = pd.read_csv(r".\similar_people.csv")
profile = profile.head(30)

list_urls_similar = list(profile['url'])

my_similar_people = df[df['is_in_similarities']].reset_index(drop =True)

# %% [markdown]
# ## Pre-Proccessing the data to word2vec model

# %%
# preparing Concatenating to train the word2vec model
s = ' '.join([x for x in df.dropna(subset = ['combined'])['combined']])

open_p = ' '.join([x for x in open_positions['Title']])

all_text = open_p + s


# replaces escape character with space
f = all_text.replace("\n", " ")
f = f.replace(",", "")
f = f.replace("-", "")

data = []

# iterate through each sentence in the file
for i in sent_tokenize(f):
    temp = []

    # tokenize the sentence into words
    for j in word_tokenize(i):
        temp.append(j.lower())

    data.append(temp)

# %% [markdown]
# ## Create the word2vec model

# %%
# create Skip Gram model word2Vec
model = gensim.models.Word2Vec(data, min_count=1, vector_size=100,window=5, sg=1)
model.save("my_word2vec.model")
model = gensim.models.Word2Vec.load("my_word2vec.model")

# %% [markdown]
# ## Calculate the similarity between the descriptions and the open positions titles

# %%
#create the similarities between descriptions to the open positions titles
similarities = {}
len_of_similar = len(my_similar_people)
#run over the descriptions
for i in range(len_of_similar):
    my_similar_people_desc = str(my_similar_people.iloc[i]['combined'])
    words_in_similar_people = [word.lower() for word in my_similar_people_desc.split(' ')]
    #run over the titles from open positions
    for title in open_positions.iloc[:]['Title']:
        counter = 0
        sum_similarities=0
        words_in_title = [word.lower() for word in title.split(' ')]
        #calculate similarity between words
        for word1 in words_in_title:
            for word2 in words_in_similar_people:
                try:
                    sum_similarities += model.wv.similarity(word1, word2)
                except:
                    continue
                counter+=1
        try:        
            similarities[my_similar_people_desc,title] = sum_similarities/counter
        except:
            continue

# %% [markdown]
# ## Get the most reccomended jobs

# %%
#get the top jobs 
top_jobs_similarites = sorted(similarities.items(), key=lambda item: item[1], reverse = True)[:3]
top_jobs = [key[0][1] for key in top_jobs_similarites]

# %%
# extract keys and values
keys = [(k[0], k[1]) for k in similarities.keys()]
values = list(similarities.values())

# create DataFrame from the dictionary
df_similarity = pd.DataFrame({'Description': [k[0] for k in keys], 'Title': [k[1] for k in keys], 'Similarity': values})

# %%
#group by similarity scores and order descending 
similarities_titles = df_similarity.groupby('Title').mean().sort_values(by = 'Similarity',ascending = False)

similarities_titles = similarities_titles.reset_index()

# %%
#get top n most reccomended titles

top_n_jobs = 20
similarities_titles = similarities_titles.merge(open_positions,left_on='Title',right_on='Title')

similarities_titles = similarities_titles.drop_duplicates(subset = ['Title','Company_Name']).sort_values(by = 'Similarity',ascending=False)

top_similarities_titles = similarities_titles.head(top_n_jobs)

# %%
top_similarities_titles
# Out:
#                                           Title  Similarity  \
# 0                       Foreman/Project Manager    0.499091
# 3     Admin/Compliance Analyst-Trainee (Korean)    0.493735
# 4          SENIOR ACCOUNTANT/ACCOUNTING MANAGER    0.493459
# 6          SENIOR ACCOUNTANT/ACCOUNTING MANAGER    0.493459
# 7                      HR Coordinator/Recruiter    0.491202
# 8                            Inside/OSP Manager    0.486677
# 9                         HR/Payroll Specialist    0.486531
# 10                      Senior Director-Finance    0.482603
# 12                        Senior Specialist-AML    0.482603
# 14                    Bookkeeper/Office Manager    0.482183
# 13                    Bookkeeper/Office Manager    0.482183
# 23  INTERVIEWER/TRANSLATOR Repost - Contractual    0.481802
# 24                        HR Coordinator- 19788    0.481265
# 25                        Payroll/HR Specialist    0.480510
# 26                     Senior Manager, CDMO/CMO    0.480496
# 27                     MDR/Vigilance Specialist    0.476281
# 28                          FP&A Senior Manager    0.475926
# 29                       Sr. Operations Manager    0.474257
# 32                            Senior Controller    0.474063
# 33                    Senior Operations Manager    0.473785
#
#                                    Company_Name  \
# 0                  Certified Apartment Staffing
# 3                                    ecocareers
# 4                 Milestone Property Management
# 6                            Source 1 Solutions
# 7                                 American Pool
# 8                                      TekSynap
# 9                               Pressed Juicery
# 10  NYU Grossman Long Island School of Medicine
# 12                                      KeyBank
# 14                        Staff Financial Group
# 13                      NorthPoint Search Group
# 23                            State of Maryland
# 24                                    TalentZök
# 25                                       Averro
# 26         NorthStar Medical Radioisotopes, LLC
# 27            Integrated Resources, Inc ( IRI )
# 28                                    Daiso USA
# 29                                           BD
# 32                           Soar Staffing, LLC
# 33                    Brightpath Associates LLC
#
#                                           Company_URL  \
# 0   https://www.linkedin.com/company/prolific-staf...
# 3   https://uk.linkedin.com/company/ecocareers?trk...
# 4   https://www.linkedin.com/company/milestone-pro...
# 6   https://www.linkedin.com/company/source-1-solu...
# 7   https://www.linkedin.com/company/american-pool...
# 8   https://www.linkedin.com/company/teksynap?trk=...
# 9   https://www.linkedin.com/company/pressedoffici...
# 10  https://www.linkedin.com/school/nyu-long-islan...
# 12  https://www.linkedin.com/company/keybank?trk=p...
# 14  https://www.linkedin.com/company/staff-financi...
# 13  https://www.linkedin.com/company/northpointsea...
# 23  https://www.linkedin.com/company/state-of-mary...
# 24  https://www.linkedin.com/company/talentz%C3%B6...
# 25  https://www.linkedin.com/company/averro?trk=pu...
# 26  https://www.linkedin.com/company/northstar-med...
# 27  https://www.linkedin.com/company/integrated-re...
# 28  https://www.linkedin.com/company/daisousa?trk=...
# 29  https://www.linkedin.com/company/bd1?trk=publi...
# 32  https://www.linkedin.com/company/soar-staffing...
# 33  https://www.linkedin.com/company/brightpathass...
#
#                Job_Location   Seniority_level Employment_type  \
# 0             Arlington, TX  Mid-Senior level       Full-time
# 3              New York, NY        Internship       Full-time
# 4              Portland, OR  Mid-Senior level       Full-time
# 6            Clearwater, FL  Mid-Senior level        Contract
# 7                 Miami, FL       Entry level       Full-time
# 8             Arlington, VA  Mid-Senior level       Full-time
# 9           Culver City, CA         Associate       Full-time
# 10             New York, NY          Director       Full-time
# 12            United States  Mid-Senior level       Full-time
# 14              Orlando, FL  Mid-Senior level       Full-time
# 13           Birmingham, AL  Mid-Senior level       Full-time
# 23  Maryland, United States       Entry level       Full-time
# 24               Orange, CA       Entry level       Full-time
# 25              Seattle, WA         Associate       Temporary
# 26               Beloit, WI  Mid-Senior level       Full-time
# 27          Mounds View, MN       Entry level        Contract
# 28              Anaheim, CA  Mid-Senior level       Full-time
# 29               Canaan, CT    Not Applicable       Full-time
# 32             New York, NY          Director       Full-time
# 33         Philadelphia, PA  Mid-Senior level       Full-time
#
#                                          Job_function  \
# 0                        Management and Manufacturing
# 3                                               Legal
# 4                     Accounting/Auditing and Finance
# 6                     Accounting/Auditing and Finance
# 7                                     Human Resources
# 8                                               Other
# 9   Human Resources, General Business, and Adminis...
# 10                                  Finance and Sales
# 12                             Information Technology
# 14                                     Administrative
# 13                                     Administrative
# 23                                     Administrative
# 24                                    Human Resources
# 25            Human Resources and Accounting/Auditing
# 26                                              Other
# 27                                              Other
# 28                    Accounting/Auditing and Finance
# 29                            Manufacturing and Other
# 32                    Accounting/Auditing and Finance
# 33                  Management, Purchasing, and Sales
#
#                                            Industries  \
# 0                             Staffing and Recruiting
# 3                             Staffing and Recruiting
# 4                               Investment Management
# 6                            Human Resources Services
# 7                             Recreational Facilities
# 8                   Information Technology & Services
# 9   Food and Beverage Retail, Food and Beverage Ma...
# 10                                   Higher Education
# 12                                            Banking
# 14                            Staffing and Recruiting
# 13                                Internet Publishing
# 23                          Government Administration
# 24                            Staffing and Recruiting
# 25  Transportation, Logistics, Supply Chain and St...
# 26                       Pharmaceutical Manufacturing
# 27                            Staffing and Recruiting
# 28                                             Retail
# 29  Biotechnology Research, Medical Equipment Manu...
# 32                            Staffing and Recruiting
# 33  Industrial Machinery Manufacturing, Machinery ...
#
#                                                 About  \
# 0   Job DescriptionWe are seeking a Foreman/Projec...
# 3   Our client is seeking anAdmin/Compliance Analy...
# 4   Job DescriptionMilestone Property Management i...
# 6   Job DescriptionABOUT THE ROLE:As the Senior Ac...
# 7   As the Human Resources Coordinator you will su...
# 8   We are seeking an Inside/OSP Manager to join o...
# 9   About Pressed JuiceryPressed Juicery is at the...
# 10  NYU Grossman School of Medicine  is one of the...
# 12  Location:For Those Who Work At Home - Various,...
